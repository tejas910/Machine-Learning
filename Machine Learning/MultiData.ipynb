# %%
import math
import pandas as pd
import pandas_datareader as web
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from keras.models import Sequential
from keras.layers import Dense,LSTM
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("c.csv")
df.sort
# Out:
#      Average Market Capitalization of listed companies during the six months ended 30 June 2020  \
# 0                                               Sr. No.
# 1                                                     1
# 2                                                     2
# 3                                                     3
# 4                                                     4
# ...                                                 ...
# 5000                                               5000
# 5001                                               5001
# 5002                                               5002
# 5003                                               5003
# 5004                                               5004
#
#                              Unnamed: 1    Unnamed: 2  Unnamed: 3  \
# 0                          Company name          ISIN  BSE Symbol
# 1               RELIANCE INDUSTRIES LTD  INE002A01018    RELIANCE
# 2        TATA CONSULTANCY SERVICES LTD.  INE467B01029         TCS
# 3                        HDFC BANK LTD.  INE040A01034    HDFCBANK
# 4              HINDUSTAN UNILEVER LTD.,  INE030A01027  HINDUNILVR
# ...                                 ...           ...         ...
# 5000     DHANASHREE ELECTRONICS LIMITED  INE413F01016         DEL
# 5001             ELLORA TRADING LIMITED  INE560T01015  ELLORATRAD
# 5002  VARDHAN CAPITAL & FINANCE LIMITED  INE128G01018  VARDHANCFL
# 5003       OCTAVIUS PLANTATIONS LIMITED  INE117S01016  OCTAVIUSPL
# 5004             BHARTIA BACHAT LIMITED  INE745R01016     BHARTIA
#
#                                           Unnamed: 4  Unnamed: 5  \
# 0     BSE 6 month Avg Total Market Cap in (Rs. Crs.)  NSE Symbol
# 1                                          893835.87    RELIANCE
# 2                                          751701.96         TCS
# 3                                          578180.54    HDFCBANK
# 4                                          472707.64  HINDUNILVR
# ...                                              ...         ...
# 5000                                            0.00         NaN
# 5001                                            0.00         NaN
# 5002                                            0.00         NaN
# 5003                                            0.00         NaN
# 5004                                            0.00         NaN
#
#                                        Unnamed: 6   Unnamed: 7  \
# 0     NSE 6 month Avg Total Market Cap (Rs. Crs.)  MSEI Symbol
# 1                                    8,93,778.21           NaN
# 2                                    7,51,744.67           NaN
# 3                                    5,77,825.75           NaN
# 4                                    4,70,496.23           NaN
# ...                                           ...          ...
# 5000                                          NaN          NaN
# 5001                                          NaN          NaN
# 5002                                          NaN          NaN
# 5003                                          NaN          NaN
# 5004                                          NaN          NaN
#
#                                           Unnamed: 8  \
# 0     MSEI 6 month Avg Total Market Cap in (Rs Crs.)
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# ...                                              ...
# 5000                                             NaN
# 5001                                             NaN
# 5002                                             NaN
# 5003                                             NaN
# 5004                                             NaN
#
#                               Unnamed: 9  \
# 0     Average of All Exchanges (Rs. Cr.)
# 1                           8,93,807.04
# 2                           7,51,723.31
# 3                           5,78,003.14
# 4                           4,71,601.93
# ...                                  ...
# 5000                                -
# 5001                                -
# 5002                                -
# 5003                                -
# 5004                                -
#
#                                             Unnamed: 10
# 0     Categorization as per SEBI Circular dated Oct ...
# 1                                            Large Cap
# 2                                            Large Cap
# 3                                            Large Cap
# 4                                            Large Cap
# ...                                                 ...
# 5000                                          Small Cap
# 5001                                          Small Cap
# 5002                                          Small Cap
# 5003                                          Small Cap
# 5004                                          Small Cap
#
# [5005 rows x 11 columns]
